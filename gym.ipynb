# %%
# import the requirements.
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file.
gym = pd.read_csv(r"C:\Users\bhatt\Downloads\gym_members_exercise_tracking.csv")

# %%
# To check columns in gym dataset.
gym.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %% [markdown]
# Going to change all upper case letters to lower case letters in gym member exercise dataset.

# %%
#To change all upper case letters to lower case letters in gym member exercise dataset.
gym.columns = map(str.lower, gym.columns)

# %%
# read 1st 3 rows of file.
gym.head(3)
# Out:
#    age  gender  weight (kg)  height (m)  max_bpm  avg_bpm  resting_bpm  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
#
#    session_duration (hours)  calories_burned workout_type  fat_percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
#
#    water_intake (liters)  workout_frequency (days/week)  experience_level  \
# 0                    3.5                              4                 3
# 1                    2.1                              4                 2
# 2                    2.3                              4                 2
#
#      bmi
# 0  30.20
# 1  32.00
# 2  24.71

# %%
# Read bottom 3 rows of file.
gym.tail(3)
# Out:
#      age  gender  weight (kg)  height (m)  max_bpm  avg_bpm  resting_bpm  \
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      session_duration (hours)  calories_burned workout_type  fat_percentage  \
# 970                      1.72            929.0       Cardio            18.8
# 971                      1.10            883.0         HIIT            28.2
# 972                      0.75            542.0     Strength            28.8
#
#      water_intake (liters)  workout_frequency (days/week)  experience_level  \
# 970                    2.7                              5                 3
# 971                    2.1                              3                 2
# 972                    3.5                              2                 1
#
#        bmi
# 970  19.50
# 971  37.74
# 972  33.38

# %%
#To check total numbers of rows and column in gym members exercise dataset.
rows, columns = gym.shape
print(f"Total Rows: {rows}")
print(f"Total Columns: {columns}")
# Out:
# Total Rows: 973
# Total Columns: 15

# %%
# To check if their is any null value in dataset.
gym.isnull().sum()
# Out:
# age                              0
# gender                           0
# weight (kg)                      0
# height (m)                       0
# max_bpm                          0
# avg_bpm                          0
# resting_bpm                      0
# session_duration (hours)         0
# calories_burned                  0
# workout_type                     0
# fat_percentage                   0
# water_intake (liters)            0
# workout_frequency (days/week)    0
# experience_level                 0
# bmi                              0
# dtype: int64

# %% [markdown]
# There are no missing values prensent in this dataset.

# %%
#TO check is there is nay duplicates
duplicates = gym.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# There is no duplicated value.

# %%
#To check if there is any duplicates
gym.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There is no duplicated integer value.

# %%
gym.dtypes
# Out:
# age                                int64
# gender                            object
# weight (kg)                      float64
# height (m)                       float64
# max_bpm                            int64
# avg_bpm                            int64
# resting_bpm                        int64
# session_duration (hours)         float64
# calories_burned                  float64
# workout_type                      object
# fat_percentage                   float64
# water_intake (liters)            float64
# workout_frequency (days/week)      int64
# experience_level                   int64
# bmi                              float64
# dtype: object

# %%
'''Descriptive Statistics for Numerical Columns generated using .describe() Method 
with round all columns to 2 decimal place
count: Total number of non-null values in the column.
mean: Average value of the column.
std: Standard deviation, showing how spread out the values are.
min: Minimum value in the column.
25%: 25th percentile (Q1).
50%: Median value (50th percentile).
75%: 75th percentile (Q3).
max: Maximum value in the column.'''
gym.describe().round(2)
# Out:
#           age  weight (kg)  height (m)  max_bpm  avg_bpm  resting_bpm  \
# count  973.00       973.00      973.00   973.00   973.00       973.00
# mean    38.68        73.85        1.72   179.88   143.77        62.22
# std     12.18        21.21        0.13    11.53    14.35         7.33
# min     18.00        40.00        1.50   160.00   120.00        50.00
# 25%     28.00        58.10        1.62   170.00   131.00        56.00
# 50%     40.00        70.00        1.71   180.00   143.00        62.00
# 75%     49.00        86.00        1.80   190.00   156.00        68.00
# max     59.00       129.90        2.00   199.00   169.00        74.00
#
#        session_duration (hours)  calories_burned  fat_percentage  \
# count                    973.00           973.00          973.00
# mean                       1.26           905.42           24.98
# std                        0.34           272.64            6.26
# min                        0.50           303.00           10.00
# ...

# %% [markdown]
#     # gym members exercise have following outcomes from above describe data
#
#     data average mean age is 38.68years with oldest age is 59years amd youngest age is
# 18years.
#
#     Max BPM average mean is significantly more than Resting BPM which is 179.88>62.22,
# low rate of Resting BPM is 62 while low Max BPM is 160 so on high Resting BPM is 74
# while high Max BPM is 199.00.
#
#     Calories Burned is higher when BMI, experience level and workout frequency is more.
# when members's BMI mean is 27.91 Experience level is 1.81 and workout frequency(days/week)
# is 3.32 calories Burned rate is 905.42. When BMI is 49.84, Experience level is 3 and
# Workout frequency(days/week) is 5 members calories Burned 1783 which is highest. While
# member's BMI is low 12.32, Experience level is low to 1 and Workout Frequency(days/week)
# is low to 2 members calories Burned rate also low as 303.
#
#      Water Intake(liters) is low 150 when less calories burned and less workout frequency
# increases as max 3.7 when calories burned with increased workout frequency.

# %%
# Create a simple pie chart
fig = plt.figure(figsize=(5, 5))
gender_counts = gym['gender'].value_counts()
gender = ['Male', 'Female']
mycolors = ['blue', 'hotpink']
values=gender_counts
plt.pie(gender_counts,labels=gender,colors=mycolors,startangle= 90,autopct='%1.1f%%')
plt.title('gender Distribution')
plt.legend(title='gender:')
loc = "corner right"
plt.show()

# %%
# To check correlation between all the values.
correlation = gym.select_dtypes("number").corr()
sns.heatmap(correlation, annot= True, cmap="tab20c", annot_kws=dict(fontsize=7, fontstyle = 'italic'))
# Out:
# <Axes: >

# %% [markdown]
# From the above figure we can conclude the session duration(hours) and calories burned have high positive correlation (.91)which means when sessuin duration(hours) increases more calories burned. After that bmi and weight have second high positive correlation(.85) after that experience level and workout frequency have 3rd  high correlation (.84) after that session hours and experience level have  positive 4th high correlation(.76) after that session duration(hours) and workout frequency have 5th high correlation(.64) after that calories burned and workout frequency have the 6th high correaltion(.58) and all other have medium and low correaltion betwen them.

# %%
gym['session_duration (hours)'].head()
# Out:
# 0    1.69
# 1    1.30
# 2    1.11
# 3    0.59
# 4    0.64
# Name: session_duration (hours), dtype: float64

# %%
#Create a bar chart.
sns.barplot(x ='gender', y = 'calories_burned', data= gym, color='hotpink')
plt.title('calories burned by gender count')
# Out:
# Text(0.5, 1.0, 'calories burned by gender count')

# %% [markdown]
# From the above bar plote we can conclude that male count have more calories burned compared to female.

# %%
#Create a scatterplot
sns.scatterplot(x="age", y="calories_burned", data=gym, color='gold')
plt.title('calories burned by age')
# Out:
# Text(0.5, 1.0, 'calories burned by age')

# %%
# Create a barplot
sns.barplot(x="workout_type", y="calories_burned", data=gym, color='brown')
plt.title('calories burned by workout type')
# Out:
# Text(0.5, 1.0, 'calories burned by workout type')

# %% [markdown]
# From the above figure we can conclude that HIIT workout type have the most calories burend outcome compare to other worktype type.

# %%
#selecting some few colomns for pairplot
cols_to_plot = ['resting_bpm', 'max_bpm', 'avg_bpm', 'bmi']
cols_to_plot
# Out:
# ['resting_bpm', 'max_bpm', 'avg_bpm', 'bmi']

# %%
#Create a pairplot
sns.pairplot(gym[cols_to_plot])

# %% [markdown]
# Second data set named gym membership details is below.

# %%
# Read the csv file.
data = pd.read_csv(r"C:\Users\bhatt\Downloads\gym_membership.csv")

# %%
# Read the first 3 rows of file.
data.head(3)
# Out:
#    id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  1997-04-18   27        Premium               4
# 1   2  Female  1977-09-18   47       Standard               3
# 2   3    Male  1983-03-30   41        Premium               1
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                         NaN
# 2                 Sat                 True                       XCore
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# 1          19:31:00           20:19:00               48      False
# 2          08:29:00           10:32:00              123       True
#
#             fav_drink  personal_training name_personal_trainer  uses_sauna
# 0                 NaN              False                   NaN        True
# ...

# %%
#Read the bottom 3 rows of dataset
data.tail(3)
# Out:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 997   998    Male  1984-10-05   40       Standard               2
# 998   999    Male  2001-02-22   23       Standard               4
# 999  1000  Female  2006-05-07   18        Premium               2
#
#           days_per_week  attend_group_lesson fav_group_lesson  \
# 997            Fri, Tue                False              NaN
# 998  Mon, Sun, Thu, Tue                 True       HIT, XCore
# 999            Thu, Tue                False              NaN
#
#     avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 997          17:21:00           19:53:00              152       True
# 998          10:23:00           12:29:00              126       True
# 999          16:41:00           19:00:00              139       True
#
#                             fav_drink  personal_training  \
# 997  coconut_pineapple, black_currant               True
# ...

# %%
# To calculating the average time in gym in hours and adding in dataset.
data['session_duration (hours)']=(data['avg_time_in_gym'])/60
data['session_duration (hours)'] = data['session_duration (hours)'].T.apply(lambda x: round(x,2))

# %%
data['session_duration (hours)'].head(3)
# Out:
# 0    1.93
# 1    0.80
# 2    2.05
# Name: session_duration (hours), dtype: float64

# %%
# Going to delete avg_time_in_gym and birthday columns.
data.drop(columns=['avg_time_in_gym', 'birthday'], inplace=True)

# %%
# To know the numbers of rows and columns in dataset.
rows, columns = data.shape

print(f"Total Rows: {rows}")
print(f"Total Columns: {columns}")
# Out:
# Total Rows: 1000
# Total Columns: 16

# %%
data.columns
# Out:
# Index(['id', 'gender', 'Age', 'abonoment_type', 'visit_per_week',
#        'days_per_week', 'attend_group_lesson', 'fav_group_lesson',
#        'avg_time_check_in', 'avg_time_check_out', 'drink_abo', 'fav_drink',
#        'personal_training', 'name_personal_trainer', 'uses_sauna',
#        'session_duration (hours)'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                            int64
# gender                       object
# Age                           int64
# abonoment_type               object
# visit_per_week                int64
# days_per_week                object
# attend_group_lesson            bool
# fav_group_lesson             object
# avg_time_check_in            object
# avg_time_check_out           object
# drink_abo                      bool
# fav_drink                    object
# personal_training              bool
# name_personal_trainer        object
# uses_sauna                     bool
# session_duration (hours)    float64
# dtype: object

# %%
data.describe().round(2)
# Out:
#             id      Age  visit_per_week  session_duration (hours)
# count  1000.00  1000.00         1000.00                   1000.00
# mean    500.50    30.60            2.68                      1.75
# std     288.82    10.82            1.24                      0.73
# min       1.00    12.00            1.00                      0.50
# 25%     250.75    21.00            2.00                      1.12
# 50%     500.50    30.00            3.00                      1.73
# 75%     750.25    40.00            3.00                      2.38
# max    1000.00    49.00            5.00                      3.00

# %% [markdown]
# According to the data set the mean age is 30years with 3 days visit per week, and

# %% [markdown]
# Changing the data set describe outcome in 2 decimal round figure.

# %% [markdown]
# Gym membership exercise have following outcomes from above describe data
#
# Members visit per week is minimum 1 day, ,max is 5 days, average is 2 days
#
# with standard deviation 1.24 which means visit per week are spread out unevenly.
#
# Members average time in gym is 105.26

# %%
gender_counts = data['gender'].value_counts()
gender_counts
# Out:
# gender
# Female    503
# Male      497
# Name: count, dtype: int64

# %% [markdown]
# THe male and female in data set are nearly equal numbers

# %%
# Create a simple pie chart
fig = plt.figure(figsize=(4, 4))
gender_counts = data['gender'].value_counts()
gender = ['Male', 'Female']
mycolors = ['blue', 'hotpink']
values=gender_counts
plt.pie(gender_counts,labels=gender,colors=mycolors,startangle= 90,autopct='%1.1f%%')
plt.title('gender Distribution')
plt.legend(title='gender:')
loc = "corner right"
plt.show()

# %% [markdown]
# From the above pie chart we can conclude that the no. of females are slightly lower than males.

# %%
# Create two barplot
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)  # 1 row, 2 columns, position 1
sns.barplot(x="gender", y="visit_per_week", data=data, color='red',)
plt.title('visit per week by gender')
plt.subplot(1, 2, 2)  # 1 row, 2 columns, position 1
sns.barplot(x="gender", y="session_duration (hours)", data=data, color='green',)
plt.title('average time in gym by gender')
# Out:
# Text(0.5, 1.0, 'average time in gym by gender')

# %% [markdown]
# From the above bar we can conclude that Females are slightly more spend time in gym.
