# %%
# import the requirements.
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read the csv file.
gym = pd.read_csv(r"C:\Users\bhatt\Downloads\gym_members_exercise_tracking.csv")
gym
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
# columns in gym dataset.
gym.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %% [markdown]
# Going to change all upper case letters to lower case letters in gym member exercise dataset.

# %%
gym.columns = map(str.lower, gym.columns)

# %%
# read 1st 5 rows from data file.
gym.head()
# Out:
#    age  gender  weight (kg)  height (m)  max_bpm  avg_bpm  resting_bpm  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    session_duration (hours)  calories_burned workout_type  fat_percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    water_intake (liters)  workout_frequency (days/week)  experience_level  \
# ...

# %%
# Read bottom 5 rows from dataset.
gym.tail()
# Out:
#      age  gender  weight (kg)  height (m)  max_bpm  avg_bpm  resting_bpm  \
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      session_duration (hours)  calories_burned workout_type  fat_percentage  \
# 968                      1.57           1364.0     Strength            10.0
# 969                      1.38           1260.0     Strength            25.0
# 970                      1.72            929.0       Cardio            18.8
# 971                      1.10            883.0         HIIT            28.2
# 972                      0.75            542.0     Strength            28.8
#
# ...

# %%
#Total numbers of rows and column in gym members exercise dataset.
rows, columns = gym.shape
print(f"Total Rows: {rows}")
print(f"Total Columns: {columns}")
# Out:
# Total Rows: 973
# Total Columns: 15

# %%
# To check if their is any null value in dataset.
gym.isnull().sum()
# Out:
# age                              0
# gender                           0
# weight (kg)                      0
# height (m)                       0
# max_bpm                          0
# avg_bpm                          0
# resting_bpm                      0
# session_duration (hours)         0
# calories_burned                  0
# workout_type                     0
# fat_percentage                   0
# water_intake (liters)            0
# workout_frequency (days/week)    0
# experience_level                 0
# bmi                              0
# dtype: int64

# %% [markdown]
# There are no missing values prensent in this dataset.

# %%
gym.dtypes
# Out:
# age                                int64
# gender                            object
# weight (kg)                      float64
# height (m)                       float64
# max_bpm                            int64
# avg_bpm                            int64
# resting_bpm                        int64
# session_duration (hours)         float64
# calories_burned                  float64
# workout_type                      object
# fat_percentage                   float64
# water_intake (liters)            float64
# workout_frequency (days/week)      int64
# experience_level                   int64
# bmi                              float64
# dtype: object

# %% [markdown]
# Descriptive Statistics for Numerical Columns generated using .describe() Method
# count: Total number of non-null values in the column.
# mean: Average value of the column.
# std: Standard deviation, showing how spread out the values are.
# min: Minimum value in the column.
# 25%: 25th percentile (Q1).
# 50%: Median value (50th percentile).
# 75%: 75th percentile (Q3).
# max: Maximum value in the column.

# %%
gym.describe()
# Out:
#               age  weight (kg)  height (m)     max_bpm     avg_bpm  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        resting_bpm  session_duration (hours)  calories_burned  fat_percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %%
# changing columns horizontally
gym.describe().T.apply(lambda x: round(x,2))
# Out:
#                                count    mean     std     min     25%     50%  \
# age                            973.0   38.68   12.18   18.00   28.00   40.00
# weight (kg)                    973.0   73.85   21.21   40.00   58.10   70.00
# height (m)                     973.0    1.72    0.13    1.50    1.62    1.71
# max_bpm                        973.0  179.88   11.53  160.00  170.00  180.00
# avg_bpm                        973.0  143.77   14.35  120.00  131.00  143.00
# resting_bpm                    973.0   62.22    7.33   50.00   56.00   62.00
# session_duration (hours)       973.0    1.26    0.34    0.50    1.04    1.26
# calories_burned                973.0  905.42  272.64  303.00  720.00  893.00
# fat_percentage                 973.0   24.98    6.26   10.00   21.30   26.20
# water_intake (liters)          973.0    2.63    0.60    1.50    2.20    2.60
# workout_frequency (days/week)  973.0    3.32    0.91    2.00    3.00    3.00
# ...

# %% [markdown]
#  gym members exercise have following outcomes from above describe data
#
#  data average mean age is 38.68years with oldest age is 59years amd youngest age is 18years.
#
#  Max BPM average mean is significantly more than Resting BPM which is 179.88>62.22, low rate of Resting BPM is 62 while low Max BPM is 160 so on high Resting BPM is 74 while high Max BPM is 199.00.
#
#  Calories Burned is higher when BMI, experience level and workout frequency is more. when members's BMI mean is 27.91 Experience level is 1.81 and workout frequency(days/week) is 3.32 calories Burned rate is 905.42. When BMI is 49.84, Experience level is 3 and Workout frequency(days/week) is 5 members calories Burned 1783 which is highest. While member's BMI is low 12.32, Experience level is low to 1 and Workout Frequency(days/week) is low to 2 members calories Burned rate also low as 303.
#
#  Water Intake(liters) is low 150 when less calories burned and less workout frequency and increases as max 3.7 when calories burned with increased workout frequency

# %%
# Create a simple pie chart
fig = plt.figure(figsize=(4, 4))
gender_counts = gym['gender'].value_counts()
gender = ['Male', 'Female']
mycolors = ['blue', 'hotpink']
values=gender_counts
plt.pie(gender_counts,labels=gender,colors=mycolors,startangle= 90,autopct='%1.1f%%')
plt.title('gender Distribution')
plt.legend(title='gender:')
loc = "corner right"
plt.show()

# %%
gym = gym(columns=['gender', age])

# %% [markdown]
# Second data set named gym membership details is below.

# %%
data = pd.read_csv(r"C:\Users\bhatt\Downloads\gym_membership.csv")

# %%
data.head()
# Out:
#    id  gender    birthday  Age abonoment_type  visit_per_week  \
# 0   1  Female  1997-04-18   27        Premium               4
# 1   2  Female  1977-09-18   47       Standard               3
# 2   3    Male  1983-03-30   41        Premium               1
# 3   4    Male  1980-04-12   44        Premium               3
# 4   5    Male  1980-09-10   44       Standard               2
#
#         days_per_week  attend_group_lesson            fav_group_lesson  \
# 0  Mon, Sat, Tue, Wed                 True  Kickboxen, BodyPump, Zumba
# 1       Mon, Sat, Wed                False                         NaN
# 2                 Sat                 True                       XCore
# 3       Sat, Tue, Wed                False                         NaN
# 4            Thu, Wed                 True        Running, Yoga, Zumba
#
#   avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 0          19:31:00           21:27:00              116      False
# ...

# %%
data.tail()
# Out:
#        id  gender    birthday  Age abonoment_type  visit_per_week  \
# 995   996  Female  1984-09-22   40       Standard               3
# 996   997  Female  2008-11-19   15       Standard               3
# 997   998    Male  1984-10-05   40       Standard               2
# 998   999    Male  2001-02-22   23       Standard               4
# 999  1000  Female  2006-05-07   18        Premium               2
#
#           days_per_week  attend_group_lesson fav_group_lesson  \
# 995       Thu, Tue, Wed                False              NaN
# 996       Fri, Mon, Sun                 True     XCore, Zumba
# 997            Fri, Tue                False              NaN
# 998  Mon, Sun, Thu, Tue                 True       HIT, XCore
# 999            Thu, Tue                False              NaN
#
#     avg_time_check_in avg_time_check_out  avg_time_in_gym  drink_abo  \
# 995          20:56:00           22:42:00              106      False
# ...

# %% [markdown]
# Calculating the average time in gym in hours and adding in dataset.

# %%
data['avg_time_in_gym_hrs']=(data['avg_time_in_gym'])/60
data['avg_time_in_gym_hrs'] = data['avg_time_in_gym_hrs'].T.apply(lambda x: round(x,2))

# %%
data['avg_time_in_gym_hrs'].head()
# Out:
# 0    1.93
# 1    0.80
# 2    2.05
# 3    1.65
# 4    0.83
# Name: avg_time_in_gym_hrs, dtype: float64

# %% [markdown]
# Going to delete avg_time_in_gym.

# %%
data.drop(columns=['avg_time_in_gym'], inplace=True)

# %% [markdown]
# To know the numbers of rows and columns in dataset.

# %%
rows, columns = data.shape

print(f"Total Rows: {rows}")
print(f"Total Columns: {columns}")
# Out:
# Total Rows: 1000
# Total Columns: 17

# %%
data.dtypes
# Out:
# id                         int64
# gender                    object
# birthday                  object
# Age                        int64
# abonoment_type            object
# visit_per_week             int64
# days_per_week             object
# attend_group_lesson         bool
# fav_group_lesson          object
# avg_time_check_in         object
# avg_time_check_out        object
# drink_abo                   bool
# fav_drink                 object
# personal_training           bool
# name_personal_trainer     object
# uses_sauna                  bool
# avg_time_in_gym_hrs      float64
# dtype: object

# %%
data.describe()
# Out:
#                 id          Age  visit_per_week  avg_time_in_gym_hrs
# count  1000.000000  1000.000000     1000.000000          1000.000000
# mean    500.500000    30.604000        2.682000             1.754260
# std     288.819436    10.817958        1.241941             0.726012
# min       1.000000    12.000000        1.000000             0.500000
# 25%     250.750000    21.000000        2.000000             1.120000
# 50%     500.500000    30.000000        3.000000             1.730000
# 75%     750.250000    40.000000        3.000000             2.380000
# max    1000.000000    49.000000        5.000000             3.000000

# %% [markdown]
# According to the data set the mean age is 30years with 3 days visit per week, and

# %% [markdown]
# Changing the data set describe outcome in 2 decimal round figure.

# %%
data.describe().T.apply(lambda x: round(x,2))
# Out:
#                       count    mean     std   min     25%     50%     75%  \
# id                   1000.0  500.50  288.82   1.0  250.75  500.50  750.25
# Age                  1000.0   30.60   10.82  12.0   21.00   30.00   40.00
# visit_per_week       1000.0    2.68    1.24   1.0    2.00    3.00    3.00
# avg_time_in_gym_hrs  1000.0    1.75    0.73   0.5    1.12    1.73    2.38
#
#                         max
# id                   1000.0
# Age                    49.0
# visit_per_week          5.0
# avg_time_in_gym_hrs     3.0

# %% [markdown]
# Gym membership exercise have following outcomes from above describe data
# Members visit per week is minimum 1 day, ,max is 5 days, average is 2 days with standard deviation 1.24 which means visit per week are spread out unevenly.
# Members average time in gym is 105.26

# %%
gender_counts = data['gender'].value_counts()
gender_counts
# Out:
# gender
# Female    503
# Male      497
# Name: count, dtype: int64

# %% [markdown]
# THe male and female in data set are nearly equal numbers

# %%
# Create a simple pie chart
fig = plt.figure(figsize=(4, 4))
gender_counts = data['gender'].value_counts()
gender = ['Male', 'Female']
mycolors = ['blue', 'hotpink']
values=gender_counts
plt.pie(gender_counts,labels=gender,colors=mycolors,startangle= 90,autopct='%1.1f%%')
plt.title('gender Distribution')
plt.legend(title='gender:')
loc = "corner right"
plt.show()

# %%
gym
